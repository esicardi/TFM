# %% [markdown]
# Configuracion de Almacenamiento

# %%
# Almacenamiento
account = "stmd01estrella"
spark.conf.set(f"fs.azure.account.key.{account}.dfs.core.windows.net","aO0SDuNHT7RQFaCaMN+YiW2R5829YhVT2GtOey+Utaw611i/J+b300eZMYSAfVbNeMz8U/X94aVC+AStgeMROw==")

# %% [markdown]
# Configuracion de Kafka

# %%
def read_config():
  config = {}
  with open("/Workspace/FileStore/client.properties") as fh:
    for line in fh:
      line = line.strip()
      if len(line) != 0 and line[0] != "#":
        parameter, value = line.strip().split('=', 1)
        config[parameter] = value.strip()
  return config

conf = read_config()

# %%
#configuracion
topic1 = "notif_dengue"
topic2="notif_leptospirosis"
topic3="notif_mening_viral"
topic4="notif_mening_bact"
datasource = "eventos"
dataset1 = topic1
dataset2 = topic2
dataset3 = topic3
dataset4 = topic4

bronze_path = f"abfss://bronze@{account}.dfs.core.windows.net"

# %%
def read_config():
  config = {}
  with open("/Workspace/FileStore/client.properties") as fh:
    for line in fh:
      line = line.strip()
      if len(line) != 0 and line[0] != "#":
        parameter, value = line.strip().split('=', 1)
        config[parameter] = value.strip()
  return config

conf = read_config()

# %%
print(conf)
# Out:
# {'bootstrap.servers': 'pkc-56d1g.eastus.azure.confluent.cloud:9092', 'security.protocol': 'SASL_SSL', 'sasl.mechanisms': 'PLAIN', 'sasl.username': 'FSTWSMEA7VVOLI3V', 'sasl.password': 'T00hs+03Dcdt7dRmPG0QvpJ5ZjYeSW34YEMa4KroUSbaOCJWGxPv0SiOVg99C9gq', 'session.timeout.ms': '45000'}

# %%
# creamos un streaming dataframe
df1 = (spark
      .readStream
      .format("kafka") 
      .option("kafka.bootstrap.servers",conf["bootstrap.servers"])
      .option("kafka.security.protocol", conf["security.protocol"])
      .option("kafka.sasl.mechanism", conf["sasl.mechanisms"])
      .option("kafka.sasl.jaas.config", 
              f"""kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{conf.get('sasl.username')}" password="{conf.get('sasl.password')}"; """)
      .option("subscribe",topic1)
      .option("startingOffsets", "earliest")
      .load()
)

# %%
# creamos un streaming dataframe
df2 = (spark
      .readStream
      .format("kafka") 
      .option("kafka.bootstrap.servers",conf["bootstrap.servers"])
      .option("kafka.security.protocol", conf["security.protocol"])
      .option("kafka.sasl.mechanism", conf["sasl.mechanisms"])
      .option("kafka.sasl.jaas.config", 
              f"""kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{conf.get('sasl.username')}" password="{conf.get('sasl.password')}"; """)
      .option("subscribe",topic2)
      .option("startingOffsets", "earliest")
      .load()
)

# %%
# creamos un streaming dataframe
df3 = (spark
      .readStream
      .format("kafka") 
      .option("kafka.bootstrap.servers",conf["bootstrap.servers"])
      .option("kafka.security.protocol", conf["security.protocol"])
      .option("kafka.sasl.mechanism", conf["sasl.mechanisms"])
      .option("kafka.sasl.jaas.config", 
              f"""kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{conf.get('sasl.username')}" password="{conf.get('sasl.password')}"; """)
      .option("subscribe",topic3)
      .option("startingOffsets", "earliest")
      .load()
)

# %%
# creamos un streaming dataframe
df4 = (spark
      .readStream
      .format("kafka") 
      .option("kafka.bootstrap.servers",conf["bootstrap.servers"])
      .option("kafka.security.protocol", conf["security.protocol"])
      .option("kafka.sasl.mechanism", conf["sasl.mechanisms"])
      .option("kafka.sasl.jaas.config", 
              f"""kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{conf.get('sasl.username')}" password="{conf.get('sasl.password')}"; """)
      .option("subscribe",topic4)
      .option("startingOffsets", "earliest")
      .load()
)

# %%
display(df1)

# %%
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th><th>topic</th><th>partition</th><th>offset</th><th>timestamp</th><th>timestampType</th></tr></thead><tbody><tr><td>Nw==</td><td>eyJub21icmUiOiAiTW9oYW1lZCIsICJhcGVsbGlkbyI6ICJCYXJyb3NvIiwgImRpcmVjY2lvbiI6ICJET0NUT1IgRlJBTkNJU0NPIFNJTU9OIDE5OTcuMCIsICJsb2NhbGlkYWQiOiAiTU9OVEVWSURFTyIsICJkZXBhcnRhbWU= (truncated)</td><td>notif_leptospirosis</td><td>0</td><td>0</td><td>2024-09-11T22:25:41.191Z</td><td>0</td></tr><tr><td>OQ==</td><td>eyJub21icmUiOiAiRXZhIE1hclx1MDBlZGEiLCAiYXBlbGxpZG8iOiAiU2FhdmVkcmEiLCAiZGlyZWNjaW9uIjogIkVTUElOT0xBLE1BUklBIDEwNDMuMCIsICJsb2NhbGlkYWQiOiAiU0FOIEpPU0UgREUgTUFZTyIsICJkZXA= (truncated)</td><td>notif_leptospirosis</td><td>0</td><td>1</td><td>2024-09-11T22:25:43.561Z</td><td>0</td></tr><tr><td>MTA=</td><td>eyJub21icmUiOiAiRWxcdTAwZWRhcyIsICJhcGVsbGlkbyI6ICJBcnRpZ2FzIiwgImRpcmVjY2lvbiI6ICJDQUxMRSA2IDMuMCIsICJsb2NhbGlkYWQiOiAiQU5UT05JT1BPTElTIiwgImRlcGFydGFtZW50byI6ICJST0NIQSI= (truncated)</td><td>notif_leptospirosis</td><td>0</td><td>2</td><td>2024-09-11T22:25:43.876Z</td><td>0</td></tr><tr><td>MTE=</td><td>eyJub21icmUiOiAiQ2FybWVsbyIsICJhcGVsbGlkbyI6ICJNb250YWxiXHUwMGUxbiIsICJkaXJlY2Npb24iOiAiTkFOQ1kgNDI3My4wIiwgImxvY2FsaWRhZCI6ICJNT05URVZJREVPIiwgImRlcGFydGFtZW50byI6ICJNT04= (truncated)</td><td>notif_leptospirosis</td><td>0</td><td>3</td><td>2024-09-11T22:25:45.018Z</td><td>0</td></tr><tr><td>MTI=</td><td>eyJub21icmUiOiAiQWxvbnNvIiwgImFwZWxsaWRvIjogIkxvc2FkYSIsICJkaXJlY2Npb24iOiAiIiwgImxvY2FsaWRhZCI6ICJBUlRJR0FTIiwgImRlcGFydGFtZW50byI6ICJBUlRJR0FTIiwgImxhdGl0dWQiOiAtMzAuMzk= (truncated)</td><td>notif_leptospirosis</td><td>0</td><td>4</td><td>2024-09-11
# %%
# Lista todas las columnas del DataFrame
columnas = df1.columns

# Imprime la lista de columnas
print("Columnas en el DataFrame:", columnas)

# Verifica si la columna 'value' está presente
if 'value' in columnas:
    print("La columna 'value' está presente.")
else:
    print("La columna 'value' NO está presente.")
# Out:
# Columnas en el DataFrame: ['key', 'value', 'topic', 'partition', 'offset', 'timestamp', 'timestampType']
# La columna 'value' está presente.

# %%
# creamos un streaming dataframe
df = (spark
      .readStream
      .format("kafka") 
      .option("kafka.bootstrap.servers",conf["bootstrap.servers"])
      .option("kafka.security.protocol", conf["security.protocol"])
      .option("kafka.sasl.mechanism", conf["sasl.mechanisms"])
      .option("kafka.sasl.jaas.config", 
              f"""kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{conf.get('sasl.username')}" password="{conf.get('sasl.password')}"; """)
      .option("subscribe",topic)
      .option("startingOffsets", "earliest")
      .load()
)

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th><th>topic</th><th>partition</th><th>offset</th><th>timestamp</th><th>timestampType</th></tr></thead><tbody><tr><td>Mg==</td><td>eyJDZWZhbGVhIjogbnVsbCwgIkNvbXByb21pc28gaGVwXHUwMGUxdGljbyI6IG51bGwsICJDb21wcm9taXNvIHJlbmFsIjogbnVsbCwgIkRvbG9yIGFiZG9taW5hbCBpbnRlbnNvIHkgY29udGludW8iOiBudWxsLCAiRG9sb3I= (truncated)</td><td>notificaciones</td><td>1</td><td>0</td><td>2024-08-11T18:55:33.296Z</td><td>0</td></tr><tr><td>Mw==</td><td>eyJDZWZhbGVhIjogbnVsbCwgIkNvbXByb21pc28gaGVwXHUwMGUxdGljbyI6IG51bGwsICJDb21wcm9taXNvIHJlbmFsIjogbnVsbCwgIkRvbG9yIGFiZG9taW5hbCBpbnRlbnNvIHkgY29udGludW8iOiBudWxsLCAiRG9sb3I= (truncated)</td><td>notificaciones</td><td>1</td><td>1</td><td>2024-08-11T18:55:35.225Z</td><td>0</td></tr><tr><td>NA==</td><td>eyJDZWZhbGVhIjogIlMiLCAiQ29tcHJvbWlzbyBoZXBcdTAwZTF0aWNvIjogbnVsbCwgIkNvbXByb21pc28gcmVuYWwiOiBudWxsLCAiRG9sb3IgYWJkb21pbmFsIGludGVuc28geSBjb250aW51byI6ICJOIiwgIkRvbG9yIHI= (truncated)</td><td>notificaciones</td><td>1</td><td>2</td><td>2024-08-11T18:55:35.84Z</td><td>0</td></tr><tr><td>NQ==</td><td>eyJDZWZhbGVhIjogIk4iLCAiQ29tcHJvbWlzbyBoZXBcdTAwZTF0aWNvIjogIlMiLCAiQ29tcHJvbWlzbyByZW5hbCI6ICJOIiwgIkRvbG9yIGFiZG9taW5hbCBpbnRlbnNvIHkgY29udGludW8iOiBudWxsLCAiRG9sb3IgcmU= (truncated)</td><td>notificaciones</td><td>1</td
taXNvIHJlbmFsIjogbnVsbCwgIkRvbG9yIGFiZG9taW5hbCBpbnRlbnNvIHkgY29udGludW8iOiBudWxsLCAiRG9sb3I= (truncated)</td><td>notificaciones</td><td>1</td><td>10</td><td>2024-08-11T18:55:56.094Z</td><td>0</td></tr><tr><td>MzE=</td><td>eyJDZWZhbGVhIjogbnVsbCwgIkNvbXByb21pc28gaGVwXHUwMGUxdGljbyI6IG51bGwsICJDb21wcm9taXNvIHJlbmFsIjogbnVsbCwgIkRvbG9yIGFiZG9taW5hbCBpbnRlbnNvIHkgY29udGludW8iOiBudWxsLCAiRG9sb3I= (truncated)</td><td>notificaciones</td><td>1</td><td>11</td><td>2024-08-11T18:55:56.881Z</td><td>0</td></tr><tr><td>MzI=</td><td>eyJDZWZhbGVhIjogbnVsbCwgIkNvbXByb21pc28gaGVwXHUwMGUxdGljbyI6IG51bGwsICJDb21wcm9taXNvIHJlbmFsIjogbnVsbCwgIkRvbG9yIGFiZG ...

# %%
from pyspark.sql.functions import col

# Crear un streaming DataFrame leyendo desde Kafka
df1 = (spark
      .readStream
      .format("kafka")
      .option("kafka.bootstrap.servers", conf["bootstrap.servers"])
      .option("kafka.security.protocol", conf["security.protocol"])
      .option("kafka.sasl.mechanism", conf["sasl.mechanisms"])
      .option("kafka.sasl.jaas.config", 
              f"""kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{conf.get('sasl.username')}" password="{conf.get('sasl.password')}"; """)
      .option("subscribe", topic1)
      .option("startingOffsets", "earliest")
      .load()
)

# Convertir las columnas key y value de binario a texto
df1 = df1.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# Ahora puedes trabajar con `key` y `value` como columnas de texto
df1.printSchema()  # Muestra el esquema para verificar que son columnas de tipo string
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- value: string (nullable = true)

# %%
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>1</td><td>{"nombre": "Pepito", "apellido": "Malo", "direccion": "5 2055.0", "localidad": null, "departamento": "TACUAREMBO", "latitud": -32.7530992984027, "longitud": -56.5165979943629, "cedula": "11654303", "fecha_nacimiento": "1985-11-11", "fecha_inicio_sintomas": "2024-03-09", "edad": 38, "sexo": "M", "evento": "Dengue", "telefono": "4631 3051", "celular": "092429096", "prestador": "MEDICA URUGUAYA", "internado": "S", "tipo_internado": "CTI", "Fiebre": "S", "Dolor abdominal intenso y continuo": "S", "Cefalea": "N", "Edemas": "S", "Dolor retroorbitario": "N", "Sangrado de Mucosas": "S", "Nauseas/V\u00f3mitos": "S", "Sangrado Grave": "S", "Exantema": "N", "Letargia o irritabilidad": "N", "Mialgias y/o artralgias": "S", "Shock": "S", "Hematocrito (%)": 55, "Plaquetas (/mm3)": 1114624, "Leucocitos sangre (/mm3)": 37944}</td></tr><tr><td>8</td><td>{"nombre": "Piedad", "apellido": "Belmonte", "direccion": "JUAN DE DIOS PEZA 2133.0", "localidad": "MONTEVIDEO", "departamento": "MONTEVIDEO", "latitud": -34.8834905816547, "longitud": -56.1356701091975, "cedula": "94423701", "fecha_nacimiento": "1996-09-02", "fecha_inicio_sintomas": "2024-01-31", "edad": 27, "sexo": "F", "evento": "Dengue", "telefono": "2160 9105", "celular": "093909620", "prestador": "CIRCULO CATOLICO", "internado": "N", "tipo_internado": "sin dato", "Fiebre": "N", "Dolor abdominal intenso y continuo": "N", "Cefalea": "S", "Edemas": "N", "Dolor retroorbitario": "S", "Sangrado de Mucosas": "S", "Nauseas/V\u00f3mitos": "S", "Sangrado Grave": "S", "Exantema": "N", "Letargia o irritabilidad": "N", "Mialgias y/o artralgias": "S", "Shock": "S", "Hematocrito (%)": 21, "Plaquetas (/mm3)": 1307932, "Leucocitos sangre (/mm3)": 16147}</td></tr><tr><td>13</td><td>{"nombre": "Jose Manuel", "apellido": "Llobet", "direccion": "", "localidad": "BELLA UNION", "departamento": "ARTIGAS", "latitud": -30.258270058992, "longitud": -57.5981095703377, "cedula": "23425699", "fecha_nacimiento": "2004-09-06", "fecha_inicio_sintomas": "2024-06-29", "edad": 19, "sexo": "M", "evento": "Dengue", "telefono": "4779 3484", "celular": "096330085", "prestador": "GREMEDA IAMPP", "internado": "S", "tipo_internado": "CTI", "Fiebre": "S", "Dolor abdominal intenso y continuo": "N", "Cefalea": "S", "Edemas": "S", "Dolor retroorbitario": "S", "Sangrado de Mucosas": "N", "Nauseas/V\u00f3mitos": "S", "Sangrado Grave": "N", "Exantema": "S", "Letargia o irritabilidad": "S", "Mialgias y/o artralgias": "N", "Shock": "S", "Hematocrito (%)": 39, "Plaquetas (/mm3)": 1126608, "Leucocitos sangre (/mm3)": 13481}</td></tr><tr><td>17</td><td>{"nombre": "Roque", "apellido": "Martinez", "direccion": "BATLLE 820.0", "localidad": "SARANDI DEL YI", "departamento": "DURAZNO", "latitud": -33.3416989751519, "longitud": -55.62372509148, "cedula": "37492101", "fecha_nacimiento": "1962-05-09", "fecha_inicio_sintomas": "2024-04-09", "edad": 61, "sexo": "M", "evento": "Dengue", "telefono": "4361 1528", "celular": "098616219", "prestador": "MEDICA URUGUAYA", "internado": "S", "tipo_internado": "CM", "Fiebre": "S", "Dolor abdominal intenso y continuo": "N", "Cefalea": "S", "Edemas": "N", "Dolor retroorbitario": "N", "Sangrado de Mucosas": "N", "Nauseas/V\u00f3mitos": "S", "Sangrado Grave": "N", "Exantema": "N", "Letargia o irritabilidad": "N", "Mialgias y/o artralgias": "S", "Shock": "S", "Hematocrito (%)": 28, "Plaquetas (/mm3)": 1416018, "Leucocitos sangre (/mm3)": 39476}</td></tr><tr><td>22</td><td>{"nombre": "Noem\u00ed", "apellido": "Carre\u00f1o", "direccion": "22 4406.0", "localidad": "LAGO JARDIN DEL BOSQUE", "departamento": "CANELONES", "latitud": -34.8318402935868, "longitud": -55.9834095583303, "cedula": "57967960", "fecha_nacimiento": "1938-11-29", "fecha_inicio_sintomas": "2024-02-25", "edad": 85, "sexo": "F", "evento": "Dengue", "telefono": "4339 6827", "cel ...

# %%
from pyspark.sql.functions import col

# Crear un streaming DataFrame leyendo desde Kafka
df2 = (spark
      .readStream
      .format("kafka")
      .option("kafka.bootstrap.servers", conf["bootstrap.servers"])
      .option("kafka.security.protocol", conf["security.protocol"])
      .option("kafka.sasl.mechanism", conf["sasl.mechanisms"])
      .option("kafka.sasl.jaas.config", 
              f"""kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{conf.get('sasl.username')}" password="{conf.get('sasl.password')}"; """)
      .option("subscribe", topic2)
      .option("startingOffsets", "earliest")
      .load()
)

# Convertir las columnas key y value de binario a texto
df2 = df2.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# Ahora puedes trabajar con `key` y `value` como columnas de texto
df2.printSchema()  # Muestra el esquema para verificar que son columnas de tipo string
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- value: string (nullable = true)

# %%
from pyspark.sql.functions import col

# Crear un streaming DataFrame leyendo desde Kafka
df3 = (spark
      .readStream
      .format("kafka")
      .option("kafka.bootstrap.servers", conf["bootstrap.servers"])
      .option("kafka.security.protocol", conf["security.protocol"])
      .option("kafka.sasl.mechanism", conf["sasl.mechanisms"])
      .option("kafka.sasl.jaas.config", 
              f"""kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{conf.get('sasl.username')}" password="{conf.get('sasl.password')}"; """)
      .option("subscribe", topic3)
      .option("startingOffsets", "earliest")
      .load()
)

# Convertir las columnas key y value de binario a texto
df3 = df3.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# Ahora puedes trabajar con `key` y `value` como columnas de texto
df1.printSchema()  # Muestra el esquema para verificar que son columnas de tipo string
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- value: string (nullable = true)

# %%
from pyspark.sql.functions import col

# Crear un streaming DataFrame leyendo desde Kafka
df4 = (spark
      .readStream
      .format("kafka")
      .option("kafka.bootstrap.servers", conf["bootstrap.servers"])
      .option("kafka.security.protocol", conf["security.protocol"])
      .option("kafka.sasl.mechanism", conf["sasl.mechanisms"])
      .option("kafka.sasl.jaas.config", 
              f"""kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{conf.get('sasl.username')}" password="{conf.get('sasl.password')}"; """)
      .option("subscribe", topic4)
      .option("startingOffsets", "earliest")
      .load()
)

# Convertir las columnas key y value de binario a texto
df4 = df4.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# Ahora puedes trabajar con `key` y `value` como columnas de texto
df1.printSchema()  # Muestra el esquema para verificar que son columnas de tipo string
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- value: string (nullable = true)

# %%
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>7</td><td>{"nombre": "Mohamed", "apellido": "Barroso", "direccion": "DOCTOR FRANCISCO SIMON 1997.0", "localidad": "MONTEVIDEO", "departamento": "MONTEVIDEO", "latitud": -34.8887288944252, "longitud": -56.1432888226468, "cedula": "96706824", "fecha_nacimiento": "2011-01-28", "fecha_inicio_sintomas": "2024-06-25", "edad": 13, "sexo": "M", "evento": "Leptospirosis", "telefono": "2268 0009", "celular": "091273949", "prestador": "COSEM IAMPP", "internado": "N", "tipo_internado": "sin dato", "Fiebre": "S", "Cefalea": "S", "S\u00edndrome hemorrag\u00edparo": "N", "Mialgias y/o artralgias": "N", "Compromiso renal": "S", "Compromiso hep\u00e1tico": "N", "Sintomatolog\u00eda digestiva": "N", "Ictericia": "N", "Hiperemia conjuntival": "N", "Neumonia/Neumonitis": "S", "Lesiones de piel": "N", "Hematocrito (%)": 38, "Plaquetas (/mm3)": 509673, "Leucocitos sangre (/mm3)": 30879, "Funci\u00f3n hep\u00e1tica BT (mg/dl)": 4.1, "Funci\u00f3n hep\u00e1tica TGO (UI/l)": 80.8, "Funci\u00f3n hep\u00e1tica LDH (mg/dl)": 1407, "Funci\u00f3n hep\u00e1tica TGP (UI/l)": 182, "Funci\u00f3n renal azoemia (mg/dl)": 9.0, "Funci\u00f3n renal creatinemia (mg/dl)": 3.7}</td></tr><tr><td>9</td><td>{"nombre": "Eva Mar\u00eda", "apellido": "Saavedra", "direccion": "ESPINOLA,MARIA 1043.0", "localidad": "SAN JOSE DE MAYO", "departamento": "SAN JOSE", "latitud": -34.3321340727727, "longitud": -56.7241206729805, "cedula": "10323541", "fecha_nacimiento": "1961-07-04", "fecha_inicio_sintomas": "2024-07-12", "edad": 63, "sexo": "F", "evento": "Leptospirosis", "telefono": "4347 3943", "celular": "092020003", "prestador": "CASMU IAMPP", "internado": "N", "tipo_internado": "sin dato", "Fiebre": "S", "Cefalea": "S", "S\u00edndrome hemorrag\u00edparo": "S", "Mialgias y/o artralgias": "N", "Compromiso renal": "N", "Compromiso hep\u00e1tico": "N", "Sintomatolog\u00eda digestiva": "N", "Ictericia": "S", "Hiperemia conjuntival": "S", "Neumonia/Neumonitis": "N", "Lesiones de piel": "N", "Hematocrito (%)": 39, "Plaquetas (/mm3)": 757569, "Leucocitos sangre (/mm3)": 27469, "Funci\u00f3n hep\u00e1tica BT (mg/dl)": 4.3, "Funci\u00f3n hep\u00e1tica TGO (UI/l)": 15.4, "Funci\u00f3n hep\u00e1tica LDH (mg/dl)": 1369, "Funci\u00f3n hep\u00e1tica TGP (UI/l)": 90, "Funci\u00f3n renal azoemia (mg/dl)": 47.7, "Funci\u00f3n renal creatinemia (mg/dl)": 6.0}</td></tr><tr><td>10</td><td>{"nombre": "El\u00edas", "apellido": "Artigas", "direccion": "CALLE 6 3.0", "localidad": "ANTONIOPOLIS", "departamento": "ROCHA", "latitud": -34.6256083277263, "longitud": -54.1534352185896, "cedula": "57508720", "fecha_nacimiento": "1943-08-04", "fecha_inicio_sintomas": "2024-06-11", "edad": 80, "sexo": "M", "evento": "Leptospirosis", "telefono": "4476 1103", "celular": "094407872", "prestador": "COMERO IAMPP", "internado": "N", "tipo_internado": "sin dato", "Fiebre": "S", "Cefalea": "N", "S\u00edndrome hemorrag\u00edparo": "S", "Mialgias y/o artralgias": "S", "Compromiso renal": "S", "Compromiso hep\u00e1tico": "S", "Sintomatolog\u00eda digestiva": "S", "Ictericia": "N", "Hiperemia conjuntival": "S", "Neumonia/Neumonitis": "S", "Lesiones de piel": "N", "Hematocrito (%)": 43, "Plaquetas (/mm3)": 748633, "Leucocitos sangre (/mm3)": 12027, "Funci\u00f3n hep\u00e1tica BT (mg/dl)": 8.2, "Funci\u00f3n hep\u00e1tica TGO (UI/l)": 37.4, "Funci\u00f3n hep\u00e1tica LDH (mg/dl)": 1396, "Funci\u00f3n hep\u00e1tica TGP (UI/l)": 86, "Funci\u00f3n renal azoemia (mg/dl)": 34.1, "Funci\u00f3n renal creatinemia (mg/dl)": 5.5}</td></tr><tr><td>11</td><td>{"nombre": "Carmelo", "apellido": "Montalb\u00e1n", "direccion": "NANCY 4273.0", "localidad": "MONTEVIDEO", "departamento": "MONTEVIDEO", "latitud": -34.8918801454262, "longitud": -56.1244194803288, "cedula": "11022611", "fecha_nacimiento": "2005-01-11", "fecha_inicio_sintomas": "2024-03-18", "edad": 19, "sexo": "M ...

# %%
display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>7</td><td>{"nombre": "Hernando", "apellido": "Cervera", "direccion": "", "localidad": "BALTASAR BRUM", "departamento": "ARTIGAS", "latitud": -30.7289692264066, "longitud": -57.3258893132628, "cedula": "30495435", "fecha_nacimiento": "1952-07-06", "fecha_inicio_sintomas": "2024-05-22", "edad": 71, "sexo": "M", "evento": "Meningitis Viral", "telefono": "4773 4705", "celular": "098075054", "prestador": "GREMEDA IAMPP", "internado": "N", "tipo_internado": "sin dato", "Fiebre": "S", "Convulsi\u00f3n": "N", "Petequias": "S", "Signos de irritaci\u00f3n men\u00edngea": "N", "Alteraci\u00f3n de conciencia": "N", "Hipopefusi\u00f3n perif\u00e9rica": "S", "Paciente Grave": "N", "Directo LCR": "Bacilos Gram negativos", "Aspecto LCR (citoqu\u00edmico)": "turbio", "Glucosa LCR (mg/dl)": 14.2, "Prote\u00ednas en LCR (mg/dl)": 40.0, "Leucocitos LCR (/mm3)": 2727, "Predominio": "PMN"}</td></tr><tr><td>9</td><td>{"nombre": "Ger\u00f3nimo", "apellido": "R\u00f3denas", "direccion": "GRAL. JOSE G. ARTIGAS 1660.0", "localidad": "RIVERA", "departamento": "RIVERA", "latitud": -30.9064740922774, "longitud": -55.5298722524401, "cedula": "58388674", "fecha_nacimiento": "1935-06-05", "fecha_inicio_sintomas": "2024-01-12", "edad": 88, "sexo": "M", "evento": "Meningitis Viral", "telefono": "4623 0820", "celular": "092029095", "prestador": "COMERI", "internado": "S", "tipo_internado": "CM", "Fiebre": "N", "Convulsi\u00f3n": "S", "Petequias": "S", "Signos de irritaci\u00f3n men\u00edngea": "S", "Alteraci\u00f3n de conciencia": "S", "Hipopefusi\u00f3n perif\u00e9rica": "S", "Paciente Grave": "S", "Directo LCR": "Cocos Gram negativos", "Aspecto LCR (citoqu\u00edmico)": "transparente", "Glucosa LCR (mg/dl)": 40.5, "Prote\u00ednas en LCR (mg/dl)": 41.2, "Leucocitos LCR (/mm3)": 1819, "Predominio": "PMN"}</td></tr><tr><td>10</td><td>{"nombre": "Adelaida", "apellido": "Amig\u00f3", "direccion": "", "localidad": "ARTIGAS", "departamento": "ARTIGAS", "latitud": -30.4096402874416, "longitud": -56.4808665988836, "cedula": "76048993", "fecha_nacimiento": "1950-12-06", "fecha_inicio_sintomas": "2024-07-26", "edad": 73, "sexo": "F", "evento": "Meningitis Viral", "telefono": "4772 6098", "celular": "092335328", "prestador": "GREMEDA IAMPP", "internado": "N", "tipo_internado": "sin dato", "Fiebre": "N", "Convulsi\u00f3n": "N", "Petequias": "N", "Signos de irritaci\u00f3n men\u00edngea": "S", "Alteraci\u00f3n de conciencia": "N", "Hipopefusi\u00f3n perif\u00e9rica": "N", "Paciente Grave": "N", "Directo LCR": "Bacilos Gram positivos", "Aspecto LCR (citoqu\u00edmico)": "turbio", "Glucosa LCR (mg/dl)": 17.8, "Prote\u00ednas en LCR (mg/dl)": 30.1, "Leucocitos LCR (/mm3)": 7066, "Predominio": "Linfocitos"}</td></tr><tr><td>11</td><td>{"nombre": "Josep", "apellido": "Polo", "direccion": "BATLLE Y ORDO\u00d1EZ, JOSE 585.0", "localidad": "SAN JOSE DE MAYO", "departamento": "SAN JOSE", "latitud": -34.3391918039772, "longitud": -56.7123377797042, "cedula": "40009155", "fecha_nacimiento": "1947-05-10", "fecha_inicio_sintomas": "2024-07-02", "edad": 77, "sexo": "M", "evento": "Meningitis Viral", "telefono": "4343 1673", "celular": "095487220", "prestador": "GREMCA", "internado": "S", "tipo_internado": "CTI", "Fiebre": "S", "Convulsi\u00f3n": "N", "Petequias": "N", "Signos de irritaci\u00f3n men\u00edngea": "S", "Alteraci\u00f3n de conciencia": "S", "Hipopefusi\u00f3n perif\u00e9rica": "S", "Paciente Grave": "S", "Directo LCR": "Bacilos Gram negativos", "Aspecto LCR (citoqu\u00edmico)": "turbio", "Glucosa LCR (mg/dl)": 59.1, "Prote\u00ednas en LCR (mg/dl)": 24.5, "Leucocitos LCR (/mm3)": 5254, "Predominio": "Linfocitos"}</td></tr><tr><td>12</td><td>{"nombre": "Flor", "apellido": "Gilabert", "direccion": "INTENDENTE SUAREZ 162.0", "localidad": "COLONIA DEL SACRAMENTO", "departamento": "COLONIA", "latitud": -34.47130179673 ...

# %%
display(df4)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>7</td><td>{"nombre": "Nicolasa", "apellido": "Murillo", "direccion": "", "localidad": "BELLA UNION", "departamento": "ARTIGAS", "latitud": -30.2569562388527, "longitud": -57.5883526151204, "cedula": "17924798", "fecha_nacimiento": "1945-08-18", "fecha_inicio_sintomas": "2024-07-22", "edad": 78, "sexo": "F", "evento": "Meningitis Bacteriana", "telefono": "4770 5116", "celular": "097427590", "prestador": "GREMEDA IAMPP", "internado": "S", "tipo_internado": "CM", "Fiebre": "S", "Convulsi\u00f3n": "S", "Petequias": "N", "Signos de irritaci\u00f3n men\u00edngea": "N", "Alteraci\u00f3n de conciencia": "S", "Hipopefusi\u00f3n perif\u00e9rica": "N", "Paciente Grave": "S", "Directo LCR": "No se observan bacterias", "Aspecto LCR (citoqu\u00edmico)": "transparente", "Glucosa LCR (mg/dl)": 31.5, "Prote\u00ednas en LCR (mg/dl)": 36.8, "Leucocitos LCR (/mm3)": 4604, "Predominio": "Linfocitos"}</td></tr><tr><td>9</td><td>{"nombre": "Marino", "apellido": "Mateu", "direccion": "ARTIGAS, 3 GRAL. JOSE 6.0", "localidad": null, "departamento": "RIO NEGRO", "latitud": -32.6926114822556, "longitud": -57.6418605648904, "cedula": "53988734", "fecha_nacimiento": "1966-12-18", "fecha_inicio_sintomas": "2024-06-30", "edad": 57, "sexo": "M", "evento": "Meningitis Bacteriana", "telefono": "4565 4873", "celular": "095588366", "prestador": "HOSPITAL EVANGELICO", "internado": "S", "tipo_internado": "CM", "Fiebre": "N", "Convulsi\u00f3n": "S", "Petequias": "N", "Signos de irritaci\u00f3n men\u00edngea": "S", "Alteraci\u00f3n de conciencia": "S", "Hipopefusi\u00f3n perif\u00e9rica": "S", "Paciente Grave": "N", "Directo LCR": "Cocos Gram negativos", "Aspecto LCR (citoqu\u00edmico)": "turbio", "Glucosa LCR (mg/dl)": 55.3, "Prote\u00ednas en LCR (mg/dl)": 29.4, "Leucocitos LCR (/mm3)": 6994, "Predominio": "PMN"}</td></tr><tr><td>10</td><td>{"nombre": "W\u00e1lter", "apellido": "Cardona", "direccion": "CONCORDIA, AVENIDA 1.0", "localidad": "SALTO", "departamento": "SALTO", "latitud": -31.364167934911, "longitud": -57.9105675489097, "cedula": "74243274", "fecha_nacimiento": "1952-02-19", "fecha_inicio_sintomas": "2024-02-19", "edad": 72, "sexo": "M", "evento": "Meningitis Bacteriana", "telefono": "4735 9849", "celular": "091328615", "prestador": "SMQS", "internado": "S", "tipo_internado": "CM", "Fiebre": "N", "Convulsi\u00f3n": "S", "Petequias": "S", "Signos de irritaci\u00f3n men\u00edngea": "N", "Alteraci\u00f3n de conciencia": "S", "Hipopefusi\u00f3n perif\u00e9rica": "S", "Paciente Grave": "N", "Directo LCR": "Cocos Gram positivos", "Aspecto LCR (citoqu\u00edmico)": "turbio", "Glucosa LCR (mg/dl)": 24.6, "Prote\u00ednas en LCR (mg/dl)": 42.4, "Leucocitos LCR (/mm3)": 685, "Predominio": "PMN"}</td></tr><tr><td>11</td><td>{"nombre": "Nazaret", "apellido": "\u00c1ngel", "direccion": "LAS VIOLETAS 954.0", "localidad": "MONTEVIDEO", "departamento": "MONTEVIDEO", "latitud": -34.8417672913095, "longitud": -56.2043416520201, "cedula": "15339537", "fecha_nacimiento": "2014-04-27", "fecha_inicio_sintomas": "2024-06-05", "edad": 10, "sexo": "M", "evento": "Meningitis Bacteriana", "telefono": "2031 2722", "celular": "091520205", "prestador": "MEDICA URUGUAYA", "internado": "S", "tipo_internado": "CM", "Fiebre": "N", "Convulsi\u00f3n": "N", "Petequias": "N", "Signos de irritaci\u00f3n men\u00edngea": "S", "Alteraci\u00f3n de conciencia": "S", "Hipopefusi\u00f3n perif\u00e9rica": "S", "Paciente Grave": "N", "Directo LCR": "Bacilos Gram positivos", "Aspecto LCR (citoqu\u00edmico)": "transparente", "Glucosa LCR (mg/dl)": 40.5, "Prote\u00ednas en LCR (mg/dl)": 30.7, "Leucocitos LCR (/mm3)": 6010, "Predominio": "PMN"}</td></tr><tr><td>12</td><td>{"nombre": "Paloma", "apellido": "Bosch", "direccion": "CORONEL JUAN JOSE QUESADA 3348.0", "localidad": "MONTEVIDEO", "departamento": "MONTEVIDEO", "latitud": -34.86649212 ...

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import from_json, col

# Definir el esquema de las columnas basado en el diccionario proporcionado
schema1 = StructType([
    StructField("nombre", StringType(), True),
    StructField("apellido", StringType(), True),
    StructField("direccion", StringType(), True),
    StructField("localidad", StringType(), True),
    StructField("departamento", StringType(), True),
    StructField("latitud", FloatType(), True),
    StructField("longitud", FloatType(), True),
    StructField("cedula", StringType(), True),
    StructField("fecha_nacimiento", StringType(), True),
    StructField("fecha_inicio_sintomas", StringType(), True),
    StructField("edad", IntegerType(), True),
    StructField("sexo", StringType(), True),
    StructField("evento", StringType(), True),
    StructField("telefono", StringType(), True),
    StructField("celular", StringType(), True),
    StructField("prestador", StringType(), True),
    StructField("internado", StringType(), True),
    StructField("tipo_internado", StringType(), True),
    StructField("fiebre", StringType(), True),
    StructField("dolor_abdominal_intenso_continuo", StringType(), True),
    StructField("cefalea", StringType(), True),
    StructField("edemas", StringType(), True),
    StructField("dolor_retroorbitario", StringType(), True),
    StructField("sangrado_mucosas", StringType(), True),
    StructField("nauseas_vomitos", StringType(), True),
    StructField("sangrado_grave", StringType(), True),
    StructField("exantema", StringType(), True),
    StructField("letargia_irritabilidad", StringType(), True),
    StructField("mialgias_artralgias", StringType(), True),
    StructField("shock", StringType(), True),
    StructField("hematocrito", IntegerType(), True),
    StructField("plaquetas", IntegerType(), True),
    StructField("leucocitos_sangre", IntegerType(), True),
    StructField("timestamp", TimestampType(), True) 
])


# Deserializar la columna 'value' que contiene el JSON en un DataFrame
df1_parsed = df1.withColumn("data", from_json(col("value"), schema1)).select("key", "data.*")

# Muestra el esquema del nuevo DataFrame
df1_parsed.printSchema()

# Ahora puedes trabajar con las columnas individuales
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- nombre: string (nullable = true)
#  |-- apellido: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- localidad: string (nullable = true)
#  |-- departamento: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)
#  |-- cedula: string (nullable = true)
#  |-- fecha_nacimiento: string (nullable = true)
#  |-- fecha_inicio_sintomas: string (nullable = true)
#  |-- edad: integer (nullable = true)
#  |-- sexo: string (nullable = true)
#  |-- evento: string (nullable = true)
#  |-- telefono: string (nullable = true)
#  |-- celular: string (nullable = true)
#  |-- prestador: string (nullable = true)
#  |-- internado: string (nullable = true)
#  |-- tipo_internado: string (nullable = true)
#  |-- fiebre: string (nullable = true)
#  |-- dolor_abdominal_intenso_continuo: string (nullable = true)
#  |-- cefalea: string (nullable = true)
#  |-- edemas: string (nullable = true)
#  |-- dolor_retroorbitario: string (nullable = true)
#  |-- sangrado_mucosas: string (nullable = true)
#  |-- nauseas_vomitos: string (nullable = true)
#  |-- sangrado_grave: string (nullable = true)
#  |-- exantema: string (nullable = true)
#  |-- letargia_irritabilidad: string (nullable = true)
#  |-- mialgias_artralgias: string (nullable = true)
#  |-- shock: string (nullable = true)
#  |-- hematocrito: integer (nullable = true)
#  |-- plaquetas: integer (nullable = true)
#  |-- leucocitos_sangre: integer (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import from_json, col

# Definir el esquema de las columnas basado en el diccionario proporcionado
schema2 = StructType([
    StructField("nombre", StringType(), True),
    StructField("apellido", StringType(), True),
    StructField("direccion", StringType(), True),
    StructField("localidad", StringType(), True),
    StructField("departamento", StringType(), True),
    StructField("latitud", FloatType(), True),
    StructField("longitud", FloatType(), True),
    StructField("cedula", StringType(), True),
    StructField("fecha_nacimiento", StringType(), True),
    StructField("fecha_inicio_sintomas", StringType(), True),
    StructField("edad", IntegerType(), True),
    StructField("sexo", StringType(), True),
    StructField("evento", StringType(), True),
    StructField("telefono", StringType(), True),
    StructField("celular", StringType(), True),
    StructField("prestador", StringType(), True),
    StructField("internado", StringType(), True),
    StructField("tipo_internado", StringType(), True),
    StructField("fiebre", StringType(), True),
    StructField("cefalea", StringType(), True),
    StructField("sindrome_hemorragiparo", StringType(), True),
    StructField("mialgias_artralgias", StringType(), True),
    StructField("compromiso_renal", StringType(), True),
    StructField("compromiso_hepatico", StringType(), True),
    StructField("sintomatologia_digestiva", StringType(), True),
    StructField("ictericia", StringType(), True),
    StructField("hiperemia_conjuntival", StringType(), True),
    StructField("neumonia_neumonitis", StringType(), True),
    StructField("lesiones_piel", StringType(), True),
    StructField("hematocrito", IntegerType(), True),
    StructField("plaquetas", IntegerType(), True),
    StructField("leucocitos_sangre", IntegerType(), True),
    StructField("funcion_hepatica_bt", FloatType(), True),
    StructField("funcion_hepatica_tgo", FloatType(), True),
    StructField("funcion_hepatica_ldh", FloatType(), True),
    StructField("funcion_hepatica_tgp", FloatType(), True),
    StructField("funcion_renal_azoemia", FloatType(), True),
    StructField("funcion_renal_creatinemia", FloatType(), True),
    StructField("timestamp", TimestampType(), True) 
])



# Deserializar la columna 'value' que contiene el JSON en un DataFrame
df2_parsed = df2.withColumn("data", from_json(col("value"), schema2)).select("key", "data.*")

# Muestra el esquema del nuevo DataFrame
df2_parsed.printSchema()

# Ahora puedes trabajar con las columnas individuales
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- nombre: string (nullable = true)
#  |-- apellido: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- localidad: string (nullable = true)
#  |-- departamento: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)
#  |-- cedula: string (nullable = true)
#  |-- fecha_nacimiento: string (nullable = true)
#  |-- fecha_inicio_sintomas: string (nullable = true)
#  |-- edad: integer (nullable = true)
#  |-- sexo: string (nullable = true)
#  |-- evento: string (nullable = true)
#  |-- telefono: string (nullable = true)
#  |-- celular: string (nullable = true)
#  |-- prestador: string (nullable = true)
#  |-- internado: string (nullable = true)
#  |-- tipo_internado: string (nullable = true)
#  |-- fiebre: string (nullable = true)
#  |-- cefalea: string (nullable = true)
#  |-- sindrome_hemorragiparo: string (nullable = true)
#  |-- mialgias_artralgias: string (nullable = true)
#  |-- compromiso_renal: string (nullable = true)
#  |-- compromiso_hepatico: string (nullable = true)
#  |-- sintomatologia_digestiva: string (nullable = true)
#  |-- ictericia: string (nullable = true)
#  |-- hiperemia_conjuntival: string (nullable = true)
#  |-- neumonia_neumonitis: string (nullable = true)
#  |-- lesiones_piel: string (nullable = true)
#  |-- hematocrito: integer (nullable = true)
#  |-- plaquetas: integer (nullable = true)
#  |-- leucocitos_sangre: integer (nullable = true)
#  |-- funcion_hepatica_bt: float (nullable = true)
#  |-- funcion_hepatica_tgo: float (nullable = true)
#  |-- funcion_hepatica_ldh: float (nullable = true)
#  |-- funcion_hepatica_tgp: float (nullable = true)
#  |-- funcion_renal_azoemia: float (nullable = true)
#  |-- funcion_renal_creatinemia: float (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import from_json, col

# Definir el esquema de las columnas basado en el diccionario proporcionado
schema3 = StructType([
    StructField("nombre", StringType(), True),
    StructField("apellido", StringType(), True),
    StructField("direccion", StringType(), True),
    StructField("localidad", StringType(), True),
    StructField("departamento", StringType(), True),
    StructField("latitud", FloatType(), True),
    StructField("longitud", FloatType(), True),
    StructField("cedula", StringType(), True),
    StructField("fecha_nacimiento", StringType(), True),
    StructField("fecha_inicio_sintomas", StringType(), True),
    StructField("edad", IntegerType(), True),
    StructField("sexo", StringType(), True),
    StructField("evento", StringType(), True),
    StructField("telefono", StringType(), True),
    StructField("celular", StringType(), True),
    StructField("prestador", StringType(), True),
    StructField("internado", StringType(), True),
    StructField("tipo_internado", StringType(), True),
    StructField("fiebre", StringType(), True),
    StructField("convulsion", StringType(), True),
    StructField("petequias", StringType(), True),
    StructField("signos_irritacion_meningea", StringType(), True),
    StructField("alteracion_conciencia", StringType(), True),
    StructField("hipopefusion_periferica", StringType(), True),
    StructField("paciente_grave", StringType(), True),
    StructField("directo_lcr", StringType(), True),
    StructField("aspecto_lcr_citoquimico", StringType(), True),
    StructField("glucosa_lcr", FloatType(), True),
    StructField("proteinas_lcr", FloatType(), True),
    StructField("leucocitos_lcr", IntegerType(), True),
    StructField("predominio", StringType(), True),
    StructField("timestamp", TimestampType(), True) 
])


# Deserializar la columna 'value' que contiene el JSON en un DataFrame
df3_parsed = df3.withColumn("data", from_json(col("value"), schema3)).select("key", "data.*")

# Muestra el esquema del nuevo DataFrame
df3_parsed.printSchema()

# Ahora puedes trabajar con las columnas individuales
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- nombre: string (nullable = true)
#  |-- apellido: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- localidad: string (nullable = true)
#  |-- departamento: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)
#  |-- cedula: string (nullable = true)
#  |-- fecha_nacimiento: string (nullable = true)
#  |-- fecha_inicio_sintomas: string (nullable = true)
#  |-- edad: integer (nullable = true)
#  |-- sexo: string (nullable = true)
#  |-- evento: string (nullable = true)
#  |-- telefono: string (nullable = true)
#  |-- celular: string (nullable = true)
#  |-- prestador: string (nullable = true)
#  |-- internado: string (nullable = true)
#  |-- tipo_internado: string (nullable = true)
#  |-- fiebre: string (nullable = true)
#  |-- convulsion: string (nullable = true)
#  |-- petequias: string (nullable = true)
#  |-- signos_irritacion_meningea: string (nullable = true)
#  |-- alteracion_conciencia: string (nullable = true)
#  |-- hipopefusion_periferica: string (nullable = true)
#  |-- paciente_grave: string (nullable = true)
#  |-- directo_lcr: string (nullable = true)
#  |-- aspecto_lcr_citoquimico: string (nullable = true)
#  |-- glucosa_lcr: float (nullable = true)
#  |-- proteinas_lcr: float (nullable = true)
#  |-- leucocitos_lcr: integer (nullable = true)
#  |-- predominio: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import from_json, col

# Definir el esquema de las columnas basado en el diccionario proporcionado
schema4 = StructType([
    StructField("nombre", StringType(), True),
    StructField("apellido", StringType(), True),
    StructField("direccion", StringType(), True),
    StructField("localidad", StringType(), True),
    StructField("departamento", StringType(), True),
    StructField("latitud", FloatType(), True),
    StructField("longitud", FloatType(), True),
    StructField("cedula", StringType(), True),
    StructField("fecha_nacimiento", StringType(), True),
    StructField("fecha_inicio_sintomas", StringType(), True),
    StructField("edad", IntegerType(), True),
    StructField("sexo", StringType(), True),
    StructField("evento", StringType(), True),
    StructField("telefono", StringType(), True),
    StructField("celular", StringType(), True),
    StructField("prestador", StringType(), True),
    StructField("internado", StringType(), True),
    StructField("tipo_internado", StringType(), True),
    StructField("fiebre", StringType(), True),
    StructField("convulsion", StringType(), True),
    StructField("petequias", StringType(), True),
    StructField("signos_irritacion_meningea", StringType(), True),
    StructField("alteracion_conciencia", StringType(), True),
    StructField("hipopefusion_periferica", StringType(), True),
    StructField("paciente_grave", StringType(), True),
    StructField("directo_lcr", StringType(), True),
    StructField("aspecto_lcr_citoquimico", StringType(), True),
    StructField("glucosa_lcr", FloatType(), True),
    StructField("proteinas_lcr", FloatType(), True),
    StructField("leucocitos_lcr", IntegerType(), True),
    StructField("predominio", StringType(), True),
    StructField("timestamp", TimestampType(), True) 
])


# Deserializar la columna 'value' que contiene el JSON en un DataFrame
df4_parsed = df4.withColumn("data", from_json(col("value"), schema4)).select("key", "data.*")

# Muestra el esquema del nuevo DataFrame
df4_parsed.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- nombre: string (nullable = true)
#  |-- apellido: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- localidad: string (nullable = true)
#  |-- departamento: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)
#  |-- cedula: string (nullable = true)
#  |-- fecha_nacimiento: string (nullable = true)
#  |-- fecha_inicio_sintomas: string (nullable = true)
#  |-- edad: integer (nullable = true)
#  |-- sexo: string (nullable = true)
#  |-- evento: string (nullable = true)
#  |-- telefono: string (nullable = true)
#  |-- celular: string (nullable = true)
#  |-- prestador: string (nullable = true)
#  |-- internado: string (nullable = true)
#  |-- tipo_internado: string (nullable = true)
#  |-- fiebre: string (nullable = true)
#  |-- convulsion: string (nullable = true)
#  |-- petequias: string (nullable = true)
#  |-- signos_irritacion_meningea: string (nullable = true)
#  |-- alteracion_conciencia: string (nullable = true)
#  |-- hipopefusion_periferica: string (nullable = true)
#  |-- paciente_grave: string (nullable = true)
#  |-- directo_lcr: string (nullable = true)
#  |-- aspecto_lcr_citoquimico: string (nullable = true)
#  |-- glucosa_lcr: float (nullable = true)
#  |-- proteinas_lcr: float (nullable = true)
#  |-- leucocitos_lcr: integer (nullable = true)
#  |-- predominio: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true
td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>16</td><td>Juliana</td><td>Rius</td><td>MAURICIO DE ZABALA 1470.0</td><td>MONTEVIDEO</td><td>MONTEVIDEO</td><td>-34. ...

# %%
bronzeTableLocation = f"{bronze_path}/{datasource}/{dataset1}/"
bronzeCheckPointLocation = f"{bronze_path}/{datasource}/{dataset1}/_checkpoint"

(df1_parsed.writeStream 
  .format("delta")
  .trigger(availableNow=True)
  .option("mergeSchema", "true")
  .option("checkpointLocation", bronzeCheckPointLocation)
  .start(bronzeTableLocation)
)

# %%
bronzeTableLocation = f"{bronze_path}/{datasource}/{dataset2}/"
bronzeCheckPointLocation = f"{bronze_path}/{datasource}/{dataset2}/_checkpoint"

(df2_parsed.writeStream 
  .format("delta")
  .trigger(availableNow=True)
  .option("mergeSchema", "true")
  .option("checkpointLocation", bronzeCheckPointLocation)
  .start(bronzeTableLocation)
)

# %%
bronzeTableLocation = f"{bronze_path}/{datasource}/{dataset3}/"
bronzeCheckPointLocation = f"{bronze_path}/{datasource}/{dataset3}/_checkpoint"

(df3_parsed.writeStream 
  .format("delta")
  .trigger(availableNow=True)
  .option("mergeSchema", "true")
  .option("checkpointLocation", bronzeCheckPointLocation)
  .start(bronzeTableLocation)
)

# %%
bronzeTableLocation = f"{bronze_path}/{datasource}/{dataset4}/"
bronzeCheckPointLocation = f"{bronze_path}/{datasource}/{dataset4}/_checkpoint"

(df4_parsed.writeStream 
  .format("delta")
  .trigger(availableNow=True)
  .option("mergeSchema", "true")
  .option("checkpointLocation", bronzeCheckPointLocation)
  .start(bronzeTableLocation)
)

# %%
display(dbutils.fs.ls(bronzeTableLocation))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>abfss://bronze@stmd01estrella.dfs.core.windows.net/eventos/notif_mening_bact/_checkpoint/</td><td>_checkpoint/</td><td>0</td><td>1726104506000</td></tr><tr><td>abfss://bronze@stmd01estrella.dfs.core.windows.net/eventos/notif_mening_bact/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1726104511000</td></tr><tr><td>abfss://bronze@stmd01estrella.dfs.core.windows.net/eventos/notif_mening_bact/part-00000-76ff372a-6b0c-43df-8d9b-c0126a061ae8-c000.snappy.parquet</td><td>part-00000-76ff372a-6b0c-43df-8d9b-c0126a061ae8-c000.snappy.parquet</td><td>14043</td><td>1726104517000</td></tr><tr><td>abfss://bronze@stmd01estrella.dfs.core.windows.net/eventos/notif_mening_bact/part-00001-3ead544b-6761-48ef-b556-e0824b00c4a9-c000.snappy.parquet</td><td>part-00001-3ead544b-6761-48ef-b556-e0824b00c4a9-c000.snappy.parquet</td><td>11551</td><td>1726104517000</td></tr><tr><td>abfss://bronze@stmd01estrella.dfs.core.windows.net/eventos/notif_mening_bact/part-00002-1dbda53e-e644-48d3-b67c-9dda4ae1572b-c000.snappy.parquet</td><td>part-00002-1dbda53e-e644-48d3-b67c-9dda4ae1572b-c000.snappy.parquet</td><td>13643</td><td>1726104517000</td></tr></tbody></table></div>

# %%
import pyspark.sql.functions as F
bronzeTableLocation1 = f"{bronze_path}/{datasource}/{dataset1}/"
df_1 = (spark.read.format("delta")
        .load(bronzeTableLocation1)
        .orderBy(F.col("timestamp").desc())
        .limit(100))
        
display(df_1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>nombre</th><th>apellido</th><th>direccion</th><th>localidad</th><th>departamento</th><th>latitud</th><th>longitud</th><th>cedula</th><th>fecha_nacimiento</th><th>fecha_inicio_sintomas</th><th>edad</th><th>sexo</th><th>evento</th><th>telefono</th><th>celular</th><th>prestador</th><th>internado</th><th>tipo_internado</th><th>fiebre</th><th>cefalea</th><th>sindrome_hemorragiparo</th><th>mialgias_artralgias</th><th>compromiso_renal</th><th>compromiso_hepatico</th><th>sintomatologia_digestiva</th><th>ictericia</th><th>hiperemia_conjuntival</th><th>neumonia_neumonitis</th><th>lesiones_piel</th><th>hematocrito</th><th>plaquetas</th><th>leucocitos_sangre</th><th>funcion_hepatica_bt</th><th>funcion_hepatica_tgo</th><th>funcion_hepatica_ldh</th><th>funcion_hepatica_tgp</th><th>funcion_renal_azoemia</th><th>funcion_renal_creatinemia</th><th>timestamp</th></tr></thead><tbody><tr><td>2</td><td>Juan</td><td>Lerma</td><td>VECINAL  3 (BARRIO SUR) 13.0</td><td>SAN CARLOS</td><td>MALDONADO</td><td>-34.79987</td><td>-54.917465</td><td>96642583</td><td>1940-04-14</td><td>2024-01-04</td><td>83</td><td>M</td><td>Leptospirosis</td><td>4298 7345</td><td>095951208</td><td>MEDICA URUGUAYA</td><td>N</td><td>sin dato</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>1</td><td>Natalia</td><td>Escolano</td><td>DULCINEA 2946.0</td><td>MONTEVIDEO</td><td>MONTEVIDEO</td><td>-34.87432</td><td>-56.1652</td><td>92564989</td><td>1947-10-08</td><td>2024-05-23</td><td>76</td><td>F</td><td>Leptospirosis</td><td>2311 3475</td><td>097690180</td><td>HOSPITAL EVANGELICO</td><td>S</td><td>CTI</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>7</td><td>Mohamed</td><td>Barroso</td><td>DOCTOR FRANCISCO SIMON 1997.0</td><td>MONTEVIDEO</td><td>MONTEVIDEO</td><td>-34.88873</td><td>-56.143288</td><td>96706824</td><td>2011-01-28</td><td>2024-06-25</td><td>13</td><td>M</td><td>Leptospirosis</td><td>2268 0009</td><td>091273949</td><td>COSEM IAMPP</td><td>N</td><td>sin dato</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8</td><td>Ismael</td><td>Izaguirre</td><td></td><td>ARTIGAS</td><td>ARTIGAS</td><td>-30.416897</td><td>-56.471302</td><td>26136223</td><td>1972-06-09</td><td>2024-02-21</td><td>51</td><td>M</td><td>Leptospirosis</td><td>4779 6391</td><td>091213213</td><td>ASSE</td><td>N</td><td>sin dato</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>3</td><td>Olegario</td><td>Miranda</td><td>LUCIO RODRIGUEZ 4827.0</td><td>MONTEVIDEO</td><td>MONTEVIDEO</td><td>-34.864197</td><td>-56.257915</td><td>81587922</td><td>1968-04-12</td><td>2024-02-25</td><td>55</td><td>M</td><td>Leptospirosis</td><td>2533 6039</td><td>097652058</td><td>ASOCIACION ESPAÑOLA</td><td>S</td><td>CTI</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td> ...

# %%
import pyspark.sql.functions as F
bronzeTableLocation3 = f"{bronze_path}/{datasource}/{dataset3}/"
df_3 = (spark.read.format("delta")
        .load(bronzeTableLocation3)
        .orderBy(F.col("timestamp").desc())
        .limit(100))
        
display(df_3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th
td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>3</td><td>Sosimo</td><td>Blázquez</td><td>DE HERRERA, DR. JUAN (SONRISA) 28.0</td><t ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import urllib.parse

# Escapar el nombre de usuario y la contraseña
username = urllib.parse.quote_plus("myAtlasDBUser")
password = urllib.parse.quote_plus("Pregunta42_")

# Construir el URI correctamente escapado
uri = f"mongodb+srv://{username}:{password}@myatlasclusteredu.x8divu1.mongodb.net/?retryWrites=true&w=majority&tls=true"

# Crear un nuevo cliente y conectarse al servidor
client = MongoClient(uri, server_api=ServerApi('1'))

# Enviar un ping para confirmar una conexión exitosa
try:
    client.admin.command('ping')
    print("¡Conexión exitosa a MongoDB!")
except Exception as e:
    print(f"Error al conectar: {e}")
# Out:
# ¡Conexión exitosa a MongoDB!

# %%
bronzeTableLocation1 = f"{bronze_path}/{datasource}/{dataset1}/"
bronzeCheckPointLocation1 = f"{bronze_path}/{datasource}/{dataset1}/_checkpoint"
bronzeTableLocation2 = f"{bronze_path}/{datasource}/{dataset2}/"
bronzeCheckPointLocation2 = f"{bronze_path}/{datasource}/{dataset2}/_checkpoint"
bronzeTableLocation3 = f"{bronze_path}/{datasource}/{dataset3}/"
bronzeCheckPointLocation3 = f"{bronze_path}/{datasource}/{dataset3}/_checkpoint"
bronzeTableLocation4 = f"{bronze_path}/{datasource}/{dataset4}/"
bronzeCheckPointLocation4 = f"{bronze_path}/{datasource}/{dataset4}/_checkpoint"

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

# Configura el URI de conexión a MongoDB Atlas
mongo_uri = "mongodb+srv://myAtlasDBUser:Pregunta42_@myatlasclusteredu.x8divu1.mongodb.net/?retryWrites=true&w=majority&tls=true"
database_name = "vigilancia"  # Cambia a tu base de datos
collection_name = "notificaciones_eventos"  # Cambia a tu colección

# Crea la sesión de Spark con la configuración para MongoDB
spark = SparkSession.builder \
    .appName("MongoDB Integration") \
    .config("spark.mongodb.output.uri", mongo_uri) \
    .config("spark.mongodb.output.database", database_name) \
    .config("spark.mongodb.output.collection", collection_name) \
    .getOrCreate()

# Configura el DataFrame que deseas escribir
df01 = (spark.read.format("delta")
        .load(bronzeTableLocation1)
        .orderBy(F.col("timestamp").desc())
        .limit(200))

# Configura las opciones de conexión
write_config = {
    "uri": mongo_uri,
    "database": database_name,
    "collection": collection_name,
    "writeConcern.w": "majority"
}

# Escribe el DataFrame en MongoDB Atlas
df01.write \
    .format("mongo") \
    .mode("append") \
    .options(**write_config) \
    .save()

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

# Configura el URI de conexión a MongoDB Atlas
mongo_uri = "mongodb+srv://myAtlasDBUser:Pregunta42_@myatlasclusteredu.x8divu1.mongodb.net/?retryWrites=true&w=majority&tls=true"
database_name = "vigilancia"  # Cambia a tu base de datos
collection_name = "notificaciones_eventos"  # Cambia a tu colección

# Crea la sesión de Spark con la configuración para MongoDB
spark = SparkSession.builder \
    .appName("MongoDB Integration") \
    .config("spark.mongodb.output.uri", mongo_uri) \
    .config("spark.mongodb.output.database", database_name) \
    .config("spark.mongodb.output.collection", collection_name) \
    .getOrCreate()

# Configura el DataFrame que deseas escribir
df02 = (spark.read.format("delta")
        .load(bronzeTableLocation2)
        .orderBy(F.col("timestamp").desc())
        .limit(200))

# Configura las opciones de conexión
write_config = {
    "uri": mongo_uri,
    "database": database_name,
    "collection": collection_name,
    "writeConcern.w": "majority"
}

# Escribe el DataFrame en MongoDB Atlas
df02.write \
    .format("mongo") \
    .mode("append") \
    .options(**write_config) \
    .save()

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

# Configura el URI de conexión a MongoDB Atlas
mongo_uri = "mongodb+srv://myAtlasDBUser:Pregunta42_@myatlasclusteredu.x8divu1.mongodb.net/?retryWrites=true&w=majority&tls=true"
database_name = "vigilancia"  # Cambia a tu base de datos
collection_name = "notificaciones_eventos"  # Cambia a tu colección

# Crea la sesión de Spark con la configuración para MongoDB
spark = SparkSession.builder \
    .appName("MongoDB Integration") \
    .config("spark.mongodb.output.uri", mongo_uri) \
    .config("spark.mongodb.output.database", database_name) \
    .config("spark.mongodb.output.collection", collection_name) \
    .getOrCreate()

# Configura el DataFrame que deseas escribir
df03 = (spark.read.format("delta")
        .load(bronzeTableLocation3)
        .orderBy(F.col("timestamp").desc())
        .limit(200))

# Configura las opciones de conexión
write_config = {
    "uri": mongo_uri,
    "database": database_name,
    "collection": collection_name,
    "writeConcern.w": "majority"
}

# Escribe el DataFrame en MongoDB Atlas
df03.write \
    .format("mongo") \
    .mode("append") \
    .options(**write_config) \
    .save()

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

# Configura el URI de conexión a MongoDB Atlas
mongo_uri = "mongodb+srv://myAtlasDBUser:Pregunta42_@myatlasclusteredu.x8divu1.mongodb.net/?retryWrites=true&w=majority&tls=true"
database_name = "vigilancia"  # Cambia a tu base de datos
collection_name = "notificaciones_eventos"  # Cambia a tu colección

# Crea la sesión de Spark con la configuración para MongoDB
spark = SparkSession.builder \
    .appName("MongoDB Integration") \
    .config("spark.mongodb.output.uri", mongo_uri) \
    .config("spark.mongodb.output.database", database_name) \
    .config("spark.mongodb.output.collection", collection_name) \
    .getOrCreate()

# Configura el DataFrame que deseas escribir
df04 = (spark.read.format("delta")
        .load(bronzeTableLocation4)
        .orderBy(F.col("timestamp").desc())
        .limit(200))

# Configura las opciones de conexión
write_config = {
    "uri": mongo_uri,
    "database": database_name,
    "collection": collection_name,
    "writeConcern.w": "majority"
}

# Escribe el DataFrame en MongoDB Atlas
df04.write \
    .format("mongo") \
    .mode("append") \
    .options(**write_config) \
    .save()

# %%
import socket

def check_port(host, port):
    sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    sock.settimeout(5)
    try:
        sock.connect((host, port))
        print(f"Puerto {port} está abierto en {host}")
    except socket.error as e:
        print(f"Error al conectar al puerto {port} en {host}: {e}")
    finally:
        sock.close()

# Reemplaza con la IP y el puerto del servidor MongoDB Atlas
check_port('myatlasclusteredu.x8divu1.mongodb.net', 27017)
# Out:
# Error al conectar al puerto 27017 en myatlasclusteredu.x8divu1.mongodb.net: [Errno -5] No address associated with hostname

# %%
spark.version
# Out:
# '3.5.0'
